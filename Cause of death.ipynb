# %%
# importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# from sklearn.preprocessing import LabeglEncoder
import warnings
warnings.filterwarnings("ignore")

# %%
main_file=pd.read_csv('cause_of_death_dataset.csv')
main_file
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
main_file.describe()
# Out:
#               Year    Meningitis  Alzheimer's Disease and Other Dementias  \
# count  6120.000000   6120.000000                              6120.000000
# mean   2004.500000   1719.701307                              4864.189379
# std       8.656149   6672.006930                             18220.659072
# min    1990.000000      0.000000                                 0.000000
# 25%    1997.000000     15.000000                                90.000000
# 50%    2004.500000    109.000000                               666.500000
# 75%    2012.000000    847.250000                              2456.250000
# max    2019.000000  98358.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          6120.000000               6120.000000    6120.000000
# mean           1173.169118               2253.600000    4140.960131
# std            4616.156238              10483.633601   18427.753137
# ...

# %%
main_file.shape
# Out:
# (6120, 34)

# %%
main_file.dtypes
# Out:
# Country/Territory                             object
# Code                                          object
# Year                                           int64
# Meningitis                                     int64
# Alzheimer's Disease and Other Dementias        int64
# Parkinson's Disease                            int64
# Nutritional Deficiencies                       int64
# Malaria                                        int64
# Drowning                                       int64
# Interpersonal Violence                         int64
# Maternal Disorders                             int64
# HIV/AIDS                                       int64
# Drug Use Disorders                             int64
# Tuberculosis                                   int64
# Cardiovascular Diseases                        int64
# Lower Respiratory Infections                   int64
# Neonatal Disorders                             int64
# Alcohol Use Disorders                          int64
# ...

# %%
#checking the missing values
sns.heatmap(main_file.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Scatter plot

# %%
sns.scatterplot(x='Year',y='Meningitis',data=main_file)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Meningitis'>

# %%
sns.scatterplot(x='Year',y='Diabetes Mellitus',data=main_file)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Diabetes Mellitus'>

# %%
sns.scatterplot(x='Year',y='Fire, Heat, and Hot Substances',data=main_file)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Fire, Heat, and Hot Substances'>

# %%
sns.scatterplot(x='Year',y='Road Injuries',data=main_file)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Road Injuries'>

# %%
sns.scatterplot(x='Year',y='Digestive Diseases',data=main_file)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Digestive Diseases'>

# %%
sns.scatterplot(x='Year',y='Nutritional Deficiencies',data=main_file)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Nutritional Deficiencies'>

# %%
plt.figure(figsize=(50,20))
sns.heatmap(main_file.corr(),cmap='Blues',linewidth=0.5, annot=True,fmt='.3f')
# Out:
# <AxesSubplot:>

# %%
#Histogram
main_file['Malaria'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
main_file["Alzheimer's Disease and Other Dementias"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
main_file['Chronic Respiratory Diseases'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
main_file['Interpersonal Violence'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
main_file['Year'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.violinplot(x='Year',data=main_file)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
main_file.skew()
# Out:
# Year                                           0.000000
# Meningitis                                     8.248599
# Alzheimer's Disease and Other Dementias        8.695288
# Parkinson's Disease                            9.321242
# Nutritional Deficiencies                      14.863496
# Malaria                                        9.159105
# Drowning                                      10.553901
# Interpersonal Violence                         5.777146
# Maternal Disorders                            12.278358
# HIV/AIDS                                       6.610169
# Drug Use Disorders                            13.367100
# Tuberculosis                                  12.022406
# Cardiovascular Diseases                        9.411914
# Lower Respiratory Infections                   9.036604
# Neonatal Disorders                            10.447536
# Alcohol Use Disorders                          9.253511
# Self-harm                                      8.973653
# ...

# %%
main_file2=main_file.copy()

# %%
main_file['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
main_file2['Total_name_of_deaths']= main_file2.sum(axis=1)
main_file2
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...
